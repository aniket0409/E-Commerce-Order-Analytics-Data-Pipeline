# %%
# %run /Workspace/Users/aniket.r.pardhi@gmail.com/E-Commerce-Order-Analytics-Data-Pipeline/notebooks/bronze/bronze_ingestion

# %%
# %run /Workspace/Users/aniket.r.pardhi@gmail.com/E-Commerce-Order-Analytics-Data-Pipeline/notebooks/silver/silver_layer

# %%
# %run /Workspace/Users/aniket.r.pardhi@gmail.com/E-Commerce-Order-Analytics-Data-Pipeline/notebooks/gold/gold_layer

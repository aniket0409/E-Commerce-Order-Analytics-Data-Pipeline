# %%
# %sql
USE CATALOG project1001;
CREATE SCHEMA IF NOT EXISTS gold;
USE SCHEMA gold;

# %%
# %run /Workspace/Users/aniket.r.pardhi@gmail.com/E-Commerce-Order-Analytics-Data-Pipeline/utils/helpers/gold_helper_functions

# %%
save_table(active_customers_per_state(read_df("project1001.silver.customers_silver")), "active_customers_per_state")

# %%
save_table(total_orders_per_day(read_df("project1001.silver.orders_silver")), "total_orders_per_day")

# %%
save_table(number_of_payments_per_day_by_method(read_df("project1001.silver.payments_silver")), "number_of_payments_per_day_by_method")

# %%
save_table(shippings_per_day_by_method(read_df("project1001.silver.shippings_silver")), "shippings_per_day_by_method")

# %%
save_table(total_items_per_order(read_df("project1001.silver.orders_details_silver")), "total_items_per_order")

# %%
save_table(customer_spending(read_df("project1001.silver.orders_details_silver")), "customer_spending")

# %%
save_table(orders_per_city(read_df("project1001.silver.orders_details_silver")), "orders_per_city")

# %%
save_table(orders_per_state(read_df("project1001.silver.orders_details_silver")), "orders_per_state")

# %%
save_table(orders_per_country(read_df("project1001.silver.orders_details_silver")), "orders_per_country")

# %%
save_table(revenue_per_category(read_df("project1001.silver.orders_details_silver")), "revenue_per_category")

# %%
save_table(returning_customers_per_item(read_df("project1001.silver.orders_details_silver")), "returning_customers_per_item")
